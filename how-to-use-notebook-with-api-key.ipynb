# %%
#First create a notebook
# go to add-ons
# click secrets and create new secret add label name like google api key and add value
# if you don't know where you can find the value check it out below
#CLICK THE LINK FOR API KEY - https://aistudio.google.com/app/apikey
#CLICK THE API KEY AND COPY
#PASTE THE KEY IN VALUE BOX AND SAVE IT.
#KAGGLE GIVE YOU A CODE SNIPPET USE IT ON YOUR NOTEBOOK FOR ACCESS THE KEY.
#if your notebook is public don't use direct api key on your notebook. Use your key as a kaggle secrets key

# %%
#code snippet 

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("Google API keys")
